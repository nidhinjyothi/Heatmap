# %%
# !nvidia-smi
# Out:
# Wed Feb 25 09:52:13 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   38C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# MyDrive  Othercomputers  Shareddrives

# %%
# !ls /content/drive/Othercomputers
# Out:
# 'My Laptop'

# %%
# !ls "/content/drive/Othercomputers/My Laptop"
# Out:
# 'Sapiens Heatmap'

# %%
# %cd "/content/drive/Othercomputers/My Laptop/Sapiens Heatmap"
# Out:
# /content/drive/Othercomputers/My Laptop/Sapiens Heatmap

# %%
# !ls
# Out:
# 2.mp4	       generate_heatmap.py  outputs	      yolov8l.engine
# config.py      main_batch.py	    __pycache__       yolov8l.onnx
# db_handler.py  main_colab.ipynb     README.md	      yolov8l.pt
# db_utils.py    main.py		    requirements.txt
# env	       model_handler.py     s3_handler.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.4/217.4 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 133.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 146.8 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.4 MB/s eta 0:00:00
# ...

# %%
# !python main_batch.py
# Out:
# Connecting to AWS RDS...
# heatmap_data: bounding_boxes column verified.
# heatmap_evidences: table verified.
# AWS RDS connection established.
#
# Loading TensorRT model...
# Loading batched model: yolov8l.pt
# Loading specialized batched engine: yolov8l.engine
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
#
# Benchmarking Batching (Batch Size 16)...
# Loading yolov8l.engine for TensorRT inference...
# [02/25/2026-09:59:36] [TRT] [I] Loaded engine size: 86 MiB
# [02/25/2026-09:59:37] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +737, now: CPU 0, GPU 820 (MiB)
# Batched Throughput: 148.9 FPS (6.7ms avg per frame)
#
#
# ───────────────────────────────────────────────────────
#   CAMERA  : Main_Store_Cam_01
#   FILE    : 2.mp4
# ───────────────────────────────────────────────────────
# ...
